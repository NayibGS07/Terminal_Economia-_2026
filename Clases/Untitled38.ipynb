# %% [markdown]
# <a href="https://colab.research.google.com/github/NayibGS07/Terminal_Economia-_2026/blob/main/Clases/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola")
# Out:
# hola
